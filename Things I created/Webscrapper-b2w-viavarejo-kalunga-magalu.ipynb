# %%
    #Importing stuff we may use

import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
import scrapy
from functools import reduce
import asyncio
import nest_asyncio
from datetime import date
import schedule
import time

# %% [markdown]
# # Importing the previous months

# %%
df = pd.read_excel('Office-Price.xlsx')

# %% [markdown]
# # Magalu

# %%
#The Urls that we will use:
urls = ['https://www.magazineluiza.com.br/pacote-microsoft-office-365-personal-1tb-onedrive-valido-por-12-meses/p/040417200/in/sowa/',
    'https://www.magazineluiza.com.br/office-2019-microsoft/p/gd33f9e5jh/in/sowa/',
    'https://www.magazineluiza.com.br/pacote-office-home-and-student-2016-32-64-bits-brazilian-fpp-79g-04766-microsoft/p/dhgee65d1j/in/sowa/',
    'https://www.magazineluiza.com.br/office-2016-home-and-student-32-64bits-microsoft/p/cd95h52822/in/sowa/',
    'https://www.magazineluiza.com.br/windows-10-pro-e-office-2019-pro-versao-download-microsoft/p/gbkf30fb1a/in/sowa/',
    'https://www.magazineluiza.com.br/microsoft-office-professional-plus-2016-fpp-32-64-bits/p/ge8757aba9/in/sowa/',
    'https://www.magazineluiza.com.br/business-office-home-2016-microsoft/p/eed9f8ca0d/in/sowa/',
    'https://www.magazineluiza.com.br/cartao-de-ativacao-microsoft-office-professional-plus-2019/p/fffc7a1c3k/in/sowa/',
    'https://www.magazineluiza.com.br/licenca-de-uso-office-2013-professional-pn-269-16094-microsoft/p/edej9b6237/in/sowa/',
    'https://www.magazineluiza.com.br/office-2019-home-business-fpp-t5d-03241-microsoft/p/jbhhchcjf4/in/sowa/',
    'https://www.magazineluiza.com.br/office-2019-home-business-box-t5d-03241-microsoft/p/ec16ac4fc5/in/sowa/']

#Getting the name and the price
price = []
title = []

for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    for i in soup.find_all('h1', class_="header-product__title"):
        title.append(i.get_text())
    for i in soup.find_all('div', class_="price-template-price-block"):
        price.append(i.get_text())

#Making it pretty

today = date.today()
df1 = pd.DataFrame(title)
df1['Preço'] = pd.DataFrame(price)
df1['Urls'] = pd.DataFrame(urls)
df1['Data'] = today.strftime("%m/%d/%Y")
df1['Varejo'] = 'Magalu'
df1.columns = ['Nome', 'Preço', 'Url', 'Data', 'Varejo']

# %%
df1
# Out:
#                                                 Nome  \
# 0  Pacote Microsoft Office 365 Personal - 1TB One...
# 1                            Office 2019 - Microsoft
# 2  Pacote Office Home And Student 2016 32/64 Bits...
# 3  Office 2016 Home And Student - 32/64bits - Mic...
# 4  Microsoft Office Professional Plus 2016 Fpp 32...
# 5              Business Office Home 2016 - Microsoft
# 6  Cartão de ativação Microsoft Office Profession...
# 7  Licença de Uso Office 2013 Professional  PN 26...
# 8  Office 2019 Home  Business Fpp T5d-03241 - Mic...
# 9  Office 2019 home business box t5d-03241 - Micr...
#
#                                          Preço  \
# 0                             por R$ 79,90
# 1                            por R$ 299,99
# 2                            por R$ 285,00
# 3   por R$ 274,55 à vista (5% de desconto)
# 4                            por R$ 418,95
# 5                            por R$ 540,00
# 6                            por R$ 977,40
# ...

# %% [markdown]
# # Kalunga

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}
response2 = requests.get('https://www.kalunga.com.br/busca/microsoft-office/1', headers=headers)
soup2 = BeautifulSoup(response2.content, "html.parser")
title2 = []
link2 = []
price2 = []
today = date.today()

for i in soup2.find_all('span', class_="h4 font-weight-bold"):
    price2.append(i.get_text())
for i in soup2.find_all('h1', class_="text-left mt-2 text-dark"):
    title2.append(i.get_text())

    link1 = []
url2 = []
for i in soup2.find_all('a', href=True):
     link2.append(i['href'])
        
for i in link2:
    if i.startswith('/prod/'):
        url2.append('https://www.kalunga.com.br' + i)

df2 = pd.DataFrame(title2)
df2['Preço'] = pd.DataFrame(price2)
df2['Url'] = pd.DataFrame(url2)
df2['Data'] = today.strftime("%m/%d/%Y")
df2['Varejo'] = 'Kalunga'
df2.columns = ['Nome', 'Preço', 'Url', 'Data', 'Varejo']

# %%
df2
# Out:
#                                                 Nome        Preço  \
# 0  Office 365 Home: 1 licença para até 6 usuários...    R$ 299,00
# 1  Office 365 Personal Assinatura Anual AOMI0056 ...    R$ 169,00
# 2  Office 365 Business Premium Assinatura Anual D...    R$ 699,00
# 3  Office 2019 Home and Student - DOWNLOAD - Micr...    R$ 499,00
# 4  Office 2019 Home and Business - DOWNLOAD - Mic...  R$ 1.299,00
# 5  Office 365 Personal: 1 Licença (PC, Mac, Andro...    R$ 239,00
# 6      Office 2019 Pro - DOWNLOAD Microsoft  UN 1 UN  R$ 2.099,00
# 7  OneDrive 1TB de Armazenamento Virtual + Office...    R$ 239,00
#
#                                                  Url        Data   Varejo
# 0  https://www.kalunga.com.br/prod/office-365-hom...  01/16/2020  Kalunga
# 1  https://www.kalunga.com.br/prod/office-365-hom...  01/16/2020  Kalunga
# 2  https://www.kalunga.com.br/prod/office-365-per...  01/16/2020  Kalunga
# 3  https://www.kalunga.com.br/prod/office-365-per...  01/16/2020  Kalunga
# ...

# %% [markdown]
# # B2W

# %% [markdown]
# Submarino

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}
response3 = requests.get('https://www.submarino.com.br/busca/microsoft-office?conteudo=Microsoft%20Office&filtro=%5B%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22microsoft%22%2C%22fixed%22%3Afalse%7D%2C%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22microsoft%20office%22%2C%22fixed%22%3Afalse%7D%2C%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22office%22%2C%22fixed%22%3Afalse%7D%5D&ordenacao=relevance&origem=nanook&suggestion=true', headers=headers)
soup3 = BeautifulSoup(response3.content, "html.parser")

title3 = []
price3 = []
url3 = []
url4 = []

for i in soup3.find_all('a', href=True):
     url3.append(i['href'])
for i in url3:
    if i.startswith('/produto/'):
        url4.append('https://www.submarino.com.br' + i)

for url in url4:
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    
    for i in soup.find_all('h1', class_="product-title__TitleUI-sc-116vf1e-2 bDZZCj TitleH1-sc-1wh9e1x-0 iNtPfX"):
        title3.append(i.get_text())
    for i in soup.find_all('span', class_="sales-price main-offer__SalesPrice-sc-1oo1w8r-1 fiWaea TextUI-sc-12tokcy-0 CIZtP"):
        price3.append(i.get_text())
df3 = pd.DataFrame(title3)
df3['Preço'] = pd.DataFrame(price3)
df3['Links'] = pd.DataFrame(url4)
df3['Data'] = today.strftime("%m/%d/%Y")
df3['Varejo'] = 'Submarino'

df3.columns = ['Nome', 'Preço', 'Url', 'Data', 'Varejo']

# %% [markdown]
# Lojas Americanas

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}
response4 = requests.get('https://www.americanas.com.br/busca/microsoft-office?conteudo=Microsoft%20Office&filtro=%5B%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22microsoft%22%2C%22fixed%22%3Afalse%7D%2C%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22microsoft%20office%22%2C%22fixed%22%3Afalse%7D%2C%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22office%22%2C%22fixed%22%3Afalse%7D%5D&ordenacao=relevance&origem=nanook&suggestion=true', headers=headers)
soup4 = BeautifulSoup(response4.content, "html.parser")

title4 = []
price4 = []
url5 = []
url6 = []

for i in soup4.find_all('a', href=True):
     url5.append(i['href'])
for i in url5:
    if i.startswith('/produto/'):
        url6.append('https://www.americanas.com.br' + i)

for url in url6:
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    
    for i in soup.find_all('h1', class_="product-title__TitleUi-sc-1r13at-0 jYPcAr TitleH1-sc-1wh9e1x-0 kSKgXt"):
        title4.append(i.get_text())
    for i in soup.find_all('span', class_="price__SalesPrice-ej7lo8-2 kjGSBk TextUI-sc-12tokcy-0 bLZSPZ"):
        price4.append(i.get_text())
        
df4 = pd.DataFrame(title4)
df4['Preço'] = pd.DataFrame(price4)
df4['Links'] = pd.DataFrame(url4)
df4['Data'] = today.strftime("%m/%d/%Y")
df4['Varejo'] = 'Lojas Americanas'

df4.columns = ['Nome', 'Preço', 'Url', 'Data', 'Varejo']

# %% [markdown]
# Shoptime

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}
response5 = requests.get('https://www.americanas.com.br/busca/microsoft-office?conteudo=Microsoft%20Office&filtro=%5B%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22microsoft%22%2C%22fixed%22%3Afalse%7D%2C%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22microsoft%20office%22%2C%22fixed%22%3Afalse%7D%2C%7B%22id%22%3A%22product_feature_marca%22%2C%22value%22%3A%22office%22%2C%22fixed%22%3Afalse%7D%5D&ordenacao=relevance&origem=nanook&suggestion=true', headers=headers)
soup5 = BeautifulSoup(response5.content, "html.parser")

title5 = []
price5 = []
url7 = []
url8 = []

for i in soup5.find_all('a', href=True):
     url7.append(i['href'])
for i in url7:
    if i.startswith('/produto/'):
        url8.append('https://www.shoptime.com.br' + i)

for url in url8:
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    
    for i in soup.find_all('h1', class_="product-title__TitleUI-sc-116vf1e-2 bDZZCj TitleH1-sc-1wh9e1x-0 fpuWQw"):
        title5.append(i.get_text())
    for i in soup.find_all('span', class_="sales-price main-offer__SalesPrice-sc-1oo1w8r-1 kdqTlB TextUI-sc-12tokcy-0 kVCAkG"):
        price5.append(i.get_text())
        
df5 = pd.DataFrame(title5)
df5['Preço'] = pd.DataFrame(price5)
df5['Links'] = pd.DataFrame(url8)
df5['Data'] = today.strftime("%m/%d/%Y")
df5['Varejo'] = 'Shoptime'

df5.columns = ['Nome', 'Preço', 'Url', 'Data', 'Varejo']

# %% [markdown]
# # Via Varejo

# %% [markdown]
# Ponto frio

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}
response6 = requests.get('https://search3.pontofrio.com.br/busca?q=Microsoft+Office&common_filter%5B3273%5D=5048&common_filter%5B1%5D=99852', headers=headers)
soup6 = BeautifulSoup(response6.content, "html.parser")

title6 = []
price6 = []
url9 = []
url10 = []

for i in soup6.find_all('a', href=True):
     url9.append(i['href'])
for i in url9:
    if i.startswith('//www.pontofrio.com.br/Informatica/SoftwareseProgramas/'):
        url10.append('https:' + i)
        
for url in url10:
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    
    for i in soup.find_all('h1', class_="fn name"):
        title6.append(i.get_text())
    for i in soup.find_all('i', class_="sale price"):
        price6.append(i.get_text())
        
df6 = pd.DataFrame(title6)
df6['Preço'] = pd.DataFrame(price6)
df6['Links'] = pd.DataFrame(url10)
df6['Data'] = today.strftime("%m/%d/%Y")
df6['Varejo'] = 'Ponto Frio'

df6.columns = ['Nome', 'Preço', 'Url', 'Data', 'Varejo']

# %% [markdown]
# Casa bahia

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}
response7 = requests.get('https://buscas2.casasbahia.com.br/busca?q=Microsoft%20office&common_filter%5B1%5D=98883', headers=headers)
soup7 = BeautifulSoup(response7.content, "html.parser")

title7 = []
price7 = []
url11 = []
url12 = []

for i in soup7.find_all('a', href=True):
     url11.append(i['href'])
for i in url11:
    if i.startswith('//www.casasbahia.com.br/Informatica/Programas/Softwares/'):
        url12.append('https:' + i)
        
for url in url12:
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    
    for i in soup.find_all('h1', class_="fn name"):
        title7.append(i.get_text())
    for i in soup.find_all('i', class_="sale price"):
        price7.append(i.get_text())
        
df7 = pd.DataFrame(title7)
df7['Preço'] = pd.DataFrame(price7)
df7['Links'] = pd.DataFrame(url12)
df7['Data'] = today.strftime("%m/%d/%Y")
df7['Varejo'] = 'Casas Bahia'

df7.columns = ['Nome', 'Preço', 'Url', 'Data', 'Varejo']

# %% [markdown]
# # Exporting to Excel

# %%
export = pd.concat([df, df1, df2, df3, df4, df5, df6, df7], axis=0, sort=False, ignore_index=True)
export.to_excel('Office-Price.xlsx', index=False)
