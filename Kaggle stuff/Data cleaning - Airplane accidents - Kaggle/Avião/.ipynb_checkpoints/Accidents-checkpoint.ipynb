# %%
#Import modules.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# # Importing files

# %%
#Link to dataset, I didn´t bought it because I wanted only the total and it was very expensive, so I typed what I needed ;) 
#Link https://www.statista.com/statistics/875319/number-flights-brazil/

total = pd.read_csv('Total_flights.csv')
total.set_index('Ano',inplace=True)

# %%
flightsT = pd.read_csv('BrFlights2.csv', encoding='latin1')

# %%
avi = pd.read_csv('accidents.csv')
avi1 = pd.DataFrame(avi)

# %% [markdown]
# # Wranggling stuff

# %%
flightsT.head()
# Out:
#         Voos        Companhia.Aerea Codigo.Tipo.Linha      Partida.Prevista  \
# 0  AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-30T08:58:00Z
# 1  AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-13T12:13:00Z
# 2  AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-29T12:13:00Z
# 3  AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-19T12:13:00Z
# 4  AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-30T12:13:00Z
#
#            Partida.Real      Chegada.Prevista          Chegada.Real  \
# 0  2016-01-30T08:58:00Z  2016-01-30T10:35:00Z  2016-01-30T10:35:00Z
# 1  2016-01-13T12:13:00Z  2016-01-13T21:30:00Z  2016-01-13T21:30:00Z
# 2  2016-01-29T12:13:00Z  2016-01-29T21:30:00Z  2016-01-29T21:30:00Z
# 3  2016-01-18T12:03:00Z  2016-01-19T21:30:00Z  2016-01-18T20:41:00Z
# 4  2016-01-30T12:13:00Z  2016-01-30T21:30:00Z  2016-01-30T21:30:00Z
#
#   Situacao.Voo                       Codigo.Justificativa Aeroporto.Origem  \
# 0    Realizado                                        NaN      Afonso Pena
# 1    Realizado                                        NaN    Salgado Filho
# 2    Realizado                                        NaN    Salgado Filho
# 3    Realizado  LIBERACAO SERV. TRAFEGO AEREO/ANTECIPACAO    Salgado Filho
# 4    Realizado                                        NaN    Salgado Filho
#
#    ... Estado.Origem Pais.Origem Aeroporto.Destino Cidade.Destino  \
# 0  ...            PR      Brasil     Salgado Filho   Porto Alegre
# 1  ...            RS      Brasil             Miami          Miami
# 2  ...            RS      Brasil             Miami          Miami
# 3  ...            RS      Brasil             Miami          Miami
# 4  ...            RS      Brasil             Miami          Miami
#
#   Estado.Destino    Pais.Destino   LongDest    LatDest   LongOrig    LatOrig
# 0             RS          Brasil -51.175381 -29.993473 -49.172481 -25.532713
# 1            N/I  Estados Unidos -80.287046  25.795865 -51.175381 -29.993473
# 2            N/I  Estados Unidos -80.287046  25.795865 -51.175381 -29.993473
# 3            N/I  Estados Unidos -80.287046  25.795865 -51.175381 -29.993473
# 4            N/I  Estados Unidos -80.287046  25.795865 -51.175381 -29.993473
#
# [5 rows x 21 columns]

# %%
flightsT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542519 entries, 0 to 2542518
# Data columns (total 21 columns):
# Voos                    object
# Companhia.Aerea         object
# Codigo.Tipo.Linha       object
# Partida.Prevista        object
# Partida.Real            object
# Chegada.Prevista        object
# Chegada.Real            object
# Situacao.Voo            object
# Codigo.Justificativa    object
# Aeroporto.Origem        object
# Cidade.Origem           object
# Estado.Origem           object
# Pais.Origem             object
# Aeroporto.Destino       object
# Cidade.Destino          object
# Estado.Destino          object
# Pais.Destino            object
# LongDest                float64
# LatDest                 float64
# LongOrig                float64
# LatOrig                 float64
# dtypes: float64(4), object(17)
# memory usage: 407.4+ MB

# %%
avi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5116 entries, 0 to 5115
# Columns: 116 entries, codigo_ocorrencia to dia_extracao
# dtypes: float64(4), int64(3), object(109)
# memory usage: 4.5+ MB

# %%
avi1.head()
# Out:
#    codigo_ocorrencia ocorrencia_classificacao  \
# 0    201305055424986                 ACIDENTE
# 1    201805021421302                INCIDENTE
# 2    201311259977425          INCIDENTE GRAVE
# 3    201605160250139          INCIDENTE GRAVE
# 4    201103187273112                INCIDENTE
#
#                                      ocorrencia_tipo ocorrencia_dia  \
# 0                              FALHA DO MOTOR EM VOO     2013-05-05
# 1                                          AERÓDROMO     2018-03-09
# 2                                     POUSO SEM TREM     2013-11-25
# 3  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO     2016-05-13
# 4                                             OUTROS     2011-03-18
#
#   ocorrencia_horario ocorrencia_cidade ocorrencia_uf ocorrencia_pais  \
# 0           11:00:00         ARIQUEMES            RO          BRASIL
# 1           22:40:00            CACOAL            RO          BRASIL
# 2           12:32:00            CACOAL            RO          BRASIL
# 3           19:19:00            CACOAL            RO          BRASIL
# 4           13:30:00        CEREJEIRAS            RO          BRASIL
#
#   ocorrencia_aerodromo aeronave_matricula  ... fator_79 fator_80 fator_81  \
# 0                 SJOG              PUAUN  ...      NÃO      NÃO      NÃO
# 1                 SSKW              PRAXL  ...      NÃO      NÃO      NÃO
# 2                 SSKW              PTRDP  ...      NÃO      NÃO      NÃO
# 3                 SSKW              PTYEL  ...      NÃO      NÃO      NÃO
# 4                 ****              PTUQW  ...      NÃO      NÃO      NÃO
#
#   fator_82  fator_83  fator_84  fator_85  fator_86 fator_87 dia_extracao
# 0      NÃO       NÃO       NÃO       NÃO       NÃO      NÃO   2018-05-06
# 1      NÃO       NÃO       NÃO       NÃO       NÃO      NÃO   2018-05-06
# 2      NÃO       NÃO       NÃO       NÃO       NÃO      NÃO   2018-05-06
# 3      NÃO       NÃO       NÃO       NÃO       NÃO      NÃO   2018-05-06
# 4      NÃO       NÃO       NÃO       NÃO       NÃO      NÃO   2018-05-06
#
# [5 rows x 116 columns]

# %%
avi1.corr()
# Out:
#                                   codigo_ocorrencia  \
# codigo_ocorrencia                          1.000000
# aeronave_quantidade_motores               -0.115886
# aeronave_peso_maximo_decolagem            -0.092152
# aeronave_quantidade_assentos              -0.110755
# aeronave_ano_fabricacao                   -0.023310
# quantidade_fatalidades                    -0.082103
# quantidade_fatores_contribuintes          -0.156575
#
#                                   aeronave_quantidade_motores  \
# codigo_ocorrencia                                   -0.115886
# aeronave_quantidade_motores                          1.000000
# aeronave_peso_maximo_decolagem                       0.486288
# aeronave_quantidade_assentos                         0.436962
# aeronave_ano_fabricacao                              0.054806
# quantidade_fatalidades                               0.429370
# quantidade_fatores_contribuintes                    -0.129330
#
#                                   aeronave_peso_maximo_decolagem  \
# codigo_ocorrencia                                      -0.092152
# aeronave_quantidade_motores                             0.486288
# aeronave_peso_maximo_decolagem                          1.000000
# aeronave_quantidade_assentos                            0.741563
# aeronave_ano_fabricacao                                -0.071916
# quantidade_fatalidades                                  0.460724
# quantidade_fatores_contribuintes                       -0.110447
#
#                                   aeronave_quantidade_assentos  \
# codigo_ocorrencia                                    -0.110755
# aeronave_quantidade_motores                           0.436962
# aeronave_peso_maximo_decolagem                        0.741563
# aeronave_quantidade_assentos                          1.000000
# aeronave_ano_fabricacao                              -0.005063
# quantidade_fatalidades                                0.613884
# quantidade_fatores_contribuintes                     -0.129524
#
#                                   aeronave_ano_fabricacao  \
# codigo_ocorrencia                               -0.023310
# aeronave_quantidade_motores                      0.054806
# aeronave_peso_maximo_decolagem                  -0.071916
# aeronave_quantidade_assentos                    -0.005063
# aeronave_ano_fabricacao                          1.000000
# quantidade_fatalidades                           0.075219
# quantidade_fatores_contribuintes                 0.026403
#
#                                   quantidade_fatalidades  \
# codigo_ocorrencia                              -0.082103
# aeronave_quantidade_motores                     0.429370
# aeronave_peso_maximo_decolagem                  0.460724
# aeronave_quantidade_assentos                    0.613884
# aeronave_ano_fabricacao                         0.075219
# quantidade_fatalidades                          1.000000
# quantidade_fatores_contribuintes                0.423661
#
#                                   quantidade_fatores_contribuintes
# codigo_ocorrencia                                        -0.156575
# aeronave_quantidade_motores                              -0.129330
# aeronave_peso_maximo_decolagem                           -0.110447
# aeronave_quantidade_assentos                             -0.129524
# aeronave_ano_fabricacao                                   0.026403
# quantidade_fatalidades                                    0.423661
# quantidade_fatores_contribuintes                          1.000000

# %%
avi1.var()
# Out:
# codigo_ocorrencia                   7.935403e+22
# aeronave_quantidade_motores         3.137074e-01
# aeronave_peso_maximo_decolagem      1.416028e+09
# aeronave_quantidade_assentos        3.260182e+03
# aeronave_ano_fabricacao             1.225898e+05
# quantidade_fatalidades              4.312541e+00
# quantidade_fatores_contribuintes    4.755198e+00
# dtype: float64

# %% [markdown]
# # Deleting and changing stuff

# %%
#Deleting columns that were used to ML and Brasil
column = list(avi1.columns.values)
column
avi1.drop([
 'fator_1',
 'fator_2',
 'fator_3',
 'fator_4',
 'fator_5',
 'fator_6',
 'fator_7',
 'fator_8',
 'fator_9',
 'fator_10',
 'fator_11',
 'fator_12',
 'fator_13',
 'fator_14',
 'fator_15',
 'fator_16',
 'fator_17',
 'fator_18',
 'fator_19',
 'fator_20',
 'fator_21',
 'fator_22',
 'fator_23',
 'fator_24',
 'fator_25',
 'fator_26',
 'fator_27',
 'fator_28',
 'fator_29',
 'fator_30',
 'fator_31',
 'fator_32',
 'fator_33',
 'fator_34',
 'fator_35',
 'fator_36',
 'fator_37',
 'fator_38',
 'fator_39',
 'fator_40',
 'fator_41',
 'fator_42',
 'fator_43',
 'fator_44',
 'fator_45',
 'fator_46',
 'fator_47',
 'fator_48',
 'fator_49',
 'fator_50',
 'fator_51',
 'fator_52',
 'fator_53',
 'fator_54',
 'fator_55',
 'fator_56',
 'fator_57',
 'fator_58',
 'fator_59',
 'fator_60',
 'fator_61',
 'fator_62',
 'fator_63',
 'fator_64',
 'fator_65',
 'fator_66',
 'fator_67',
 'fator_68',
 'fator_69',
 'fator_70',
 'fator_71',
 'fator_72',
 'fator_73',
 'fator_74',
 'fator_75',
 'fator_76',
 'fator_77',
 'fator_78',
 'fator_79',
 'fator_80',
 'fator_81',
 'fator_82',
 'fator_83',
 'fator_84',
 'fator_85',
 'fator_86',
 'fator_87',
'ocorrencia_pais'], inplace=True, axis=1)

"""The 'factor' was taking off because we are not using any ML to this model, and 'ocorrencia_pais' was also removed because all of the accidents happened in Brazil"""
# Out:
# "The 'factor' was taking off because we are not using any ML to this model, and 'ocorrencia_pais' was also removed because all of the accidents happened in Brazil"

# %%
#Creating year and changing date to 'datetime'.

avi1['ocorrencia_dia'] = pd.to_datetime(avi1['ocorrencia_dia'])
avi1['Dia'] = avi1['ocorrencia_dia'].map(lambda x: x.day)
avi1['Ano'] = avi1['ocorrencia_dia'].map(lambda x: x.year)
avi1['Mes'] = avi1['ocorrencia_dia'].map(lambda x: x.month)

avi1.head()
# Out:
#    codigo_ocorrencia ocorrencia_classificacao  \
# 0    201305055424986                 ACIDENTE
# 1    201805021421302                INCIDENTE
# 2    201311259977425          INCIDENTE GRAVE
# 3    201605160250139          INCIDENTE GRAVE
# 4    201103187273112                INCIDENTE
#
#                                      ocorrencia_tipo ocorrencia_dia  \
# 0                              FALHA DO MOTOR EM VOO     2013-05-05
# 1                                          AERÓDROMO     2018-03-09
# 2                                     POUSO SEM TREM     2013-11-25
# 3  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO     2016-05-13
# 4                                             OUTROS     2011-03-18
#
#   ocorrencia_horario ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0           11:00:00         ARIQUEMES            RO                 SJOG
# 1           22:40:00            CACOAL            RO                 SSKW
# 2           12:32:00            CACOAL            RO                 SSKW
# 3           19:19:00            CACOAL            RO                 SSKW
# 4           13:30:00        CEREJEIRAS            RO                 ****
#
#   aeronave_matricula aeronave_equipamento  ... aeronave_destino_voo  \
# 0              PUAUN            ULTRALEVE  ...                 ****
# 1              PRAXL                AVIÃO  ...                 SBCY
# 2              PTRDP                AVIÃO  ...                 SSKW
# 3              PTYEL          HELICÓPTERO  ...                 SSKW
# 4              PTUQW                AVIÃO  ...                 ****
#
#      aeronave_fase_voo  aeronave_tipo_operacao  aeronave_nivel_dano  \
# 0  CIRCUITO DE TRÁFEGO        VOO EXPERIMENTAL          SUBSTANCIAL
# 1                 TÁXI             VOO REGULAR               NENHUM
# 2                POUSO              TÁXI AÉREO          SUBSTANCIAL
# 3    APROXIMAÇÃO FINAL  OPERAÇÃO ESPECIALIZADA                 LEVE
# 4                 TÁXI  OPERAÇÃO ESPECIALIZADA          SUBSTANCIAL
#
#    quantidade_fatalidades  quantidade_fatores_contribuintes  dia_extracao Dia  \
# 0                     NaN                                 0    2018-05-06   5
# 1                     NaN                                 0    2018-05-06   9
# 2                     NaN                                 2    2018-05-06  25
# 3                     NaN                                 0    2018-05-06  13
# 4                     NaN                                 0    2018-05-06  18
#
#     Ano Mes
# 0  2013   5
# 1  2018   3
# 2  2013  11
# 3  2016   5
# 4  2011   3
#
# [5 rows x 31 columns]

# %%
#Checking to see if I didn´t broke anything.
avi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5116 entries, 0 to 5115
# Data columns (total 31 columns):
# codigo_ocorrencia                   5116 non-null int64
# ocorrencia_classificacao            5116 non-null object
# ocorrencia_tipo                     5116 non-null object
# ocorrencia_dia                      5116 non-null datetime64[ns]
# ocorrencia_horario                  5116 non-null object
# ocorrencia_cidade                   5116 non-null object
# ocorrencia_uf                       5116 non-null object
# ocorrencia_aerodromo                5116 non-null object
# aeronave_matricula                  5116 non-null object
# aeronave_equipamento                5116 non-null object
# aeronave_fabricante                 5116 non-null object
# aeronave_modelo                     5116 non-null object
# aeronave_tipo_motor                 5116 non-null object
# aeronave_quantidade_motores         5087 non-null float64
# aeronave_peso_maximo_decolagem      5116 non-null int64
# aeronave_quantidade_assentos        5040 non-null float64
# aeronave_ano_fabricacao             5053 non-null float64
# aeronave_pais_registro              5116 non-null object
# aeronave_categoria_registro         5116 non-null object
# aeronave_segmento_aviacao           5116 non-null object
# aeronave_origem_voo                 5116 non-null object
# aeronave_destino_voo                5116 non-null object
# aeronave_fase_voo                   5116 non-null object
# aeronave_tipo_operacao              5116 non-null object
# aeronave_nivel_dano                 5116 non-null object
# quantidade_fatalidades              385 non-null float64
# quantidade_fatores_contribuintes    5116 non-null int64
# dia_extracao                        5116 non-null object
# Dia                                 5116 non-null int64
# Ano                                 5116 non-null int64
# Mes                                 5116 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(20)
# memory usage: 1.2+ MB

# %% [markdown]
# # Analysing stuff

# %%
"""Conseguimos observar que existem correlações obvias, como quantidades de assentos e falatalidade, ou quantidade de assentos e número de motos no avião. Com isso não  podemos tirar nenhuma conclusão avançada sobre o assunto."""

f, ax = plt.subplots(figsize=(15,6))
sns.heatmap(avi1.corr(), annot=True, fmt='.2f', ax=ax, linecolor='black', lw=.7)

# %%
#Marketshare of the brazilian market.
mshare = flightsT['Companhia.Aerea'].value_counts()
mask = mshare > 100000
mshare2 = mshare[mask]
pd.DataFrame(mshare2)

# summ = mshare.sum()
# minus = mshare2.sum()
# Other = mshare.sum() - minus
# Out:
#                 Companhia.Aerea
# GOL                      759191
# AZUL                     742495
# TAM                      554099
# AVIANCA BRASIL           183913

# %%
"""As we can see we have few relevant companies in the market."""
mshare2.plot(kind='pie', subplots=True, label="." ,figsize=(8, 8))
plt.savefig("marketshare")

# %%
#The number of accidents versus the total number of flights.
gb3 = avi1[['Ano','quantidade_fatalidades']].groupby('Ano').sum()

percent = (gb3.values*100)/sum(total.values)

pd.DataFrame(percent)

total['Accidents'] = gb3.values
total['Accidents Percent'] = percent
total['Accidents'].astype(int)

total['Flights'].sum()
total
total.to_excel("Totalnumbers.xls")

# %%
#Total number graph:
"""It´s so small that in a plot bar you can´t see."""
total2 = total.drop('Accidents Percent', axis= 1)
total2

total2.plot.bar(figsize=(8, 4))
plt.savefig('percentacident')

# %%
#Finding the cities with the most number of accidents:
mask = avi1['ocorrencia_uf'].value_counts() 
mask2 = mask > 60
mask2
city = mask[mask2]
city

city.plot.bar(color='indigo', figsize=(8, 4))
plt.savefig('accidentsraw')

"""As you can see in the plot bellow most of the acccidents happens in the southeast of Brazil."""
# Out:
# 'As you can see in the plot bellow most of the acccidents happens in the southeast of Brazil.'

# %%
#How many people died in each UF in total.
gb2 = avi1[['ocorrencia_uf','quantidade_fatalidades']].groupby('ocorrencia_uf').sum()
gb2.plot.bar(color='indigo', figsize=(8, 4))


"""Waaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaay more people dies in SP."""
# Out:
# 'Waaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaay more people dies in SP.'

# %%
flightR = flightsT['Estado.Origem'].value_counts()
flightR2 = flightR.apply(lambda x: (x*100)/sum(flightR))
flightP = pd.DataFrame(flightR2)   

city2 = city.apply(lambda x: (x*100)/sum(city))
flightP.columns = ['Percentage of flights']

# %%
flightP['Percentage of accidents'] = city2
flightP.head(4).plot.bar(figsize=(8, 4))
plt.savefig('accidentsper')

"""as you can see there is fewer accidents in SP compared to the percent of the number of flights."""
# Out:
# 'as you can see there is fewer accidents in SP compared to the percent of the number of flights.'

# %%
#Number of accidents through the years.
sns.distplot(avi1["Ano"], color='indigo')
plt.xlim([2008,2018])

plt.savefig('accidentsperyear')

# %%
#Number of deaths through the years.
"""We can get to the conclusion that in 2016 a lot of died in fewer accidents (the accidents were bloodier (I don´t know if this word exist))"""
gb2 = avi1[['Ano','quantidade_fatalidades']].groupby('Ano').sum()
gb2.plot(figsize=(8, 4))

# %%
#Category of the accidents.
# Tipos de classificações existentes na base de dados
plt.style.use("ggplot")

#Visualizando melhor em um gráfico
avi1['ocorrencia_classificacao'].value_counts().plot(kind='pie', subplots=True, label="Classificação de Acidentes" )
plt.savefig('grav')

# %%
#The most frequent kinds of accidents.
plt.style.use("ggplot")
a = avi1['ocorrencia_tipo'].value_counts()
a.head(10).plot(kind='barh', subplots=True, label="Tipos de ocorrência" , color='indigo')
plt.xticks(rotation=80)
"""Como podemos ver, falha do motor em voo é a principal ocorrência."""
plt.savefig('tipo')

# %%
#Model and manifacture of planes that suffered the most number of accidents:
avi1['aeronave_modelo'].value_counts()
con = avi1[['aeronave_modelo','aeronave_fabricante']].groupby('aeronave_modelo').sum()
pd.DataFrame(con)

mask6 = avi1['aeronave_modelo'].value_counts() 
mask7 = mask6 > 60

model = mask6[mask7]
pd.DataFrame(model)
model.columns = 'Numero de acidentes'
model.plot.bar( subplots=True, label="Aviões" ,figsize=(8, 4), color='indigo')
plt.savefig('Avi')

# %%
gb = avi1[['aeronave_modelo','aeronave_quantidade_assentos']].groupby('aeronave_modelo').mean()

# %%
#Manufacture of the models that fall the most.
model['aeronave_modelo'] = model.index

result = con.merge(model, how='right', left_on="aeronave_modelo", right_index=True)
result.columns = 'Fabricante', 'Acidentes'

result
# Out:
#                                                         Fabricante  \
# aeronave_modelo
# 152              CESSNA AIRCRAFTCESSNA AIRCRAFTCESSNA AIRCRAFTC...
# 58               BEECH AIRCRAFTBEECH AIRCRAFTBEECH AIRCRAFTBEEC...
# 737-8EH          BOEING COMPANYBOEING COMPANYBOEING COMPANYBOEI...
# A320-232         AIRBUS INDUSTRIEAIRBUS INDUSTRIEAIRBUS INDUSTR...
# AB-115           AERO BOEROAERO BOEROAERO BOEROAERO BOEROAERO B...
# ATR-72-212A      AEROSPATIALE AND ALENIAAEROSPATIALE AND ALENIA...
# EMB-201A         NEIVA INDUSTRIA AERONAUTICANEIVA INDUSTRIA AER...
# EMB-202          NEIVA INDUSTRIA AERONAUTICANEIVA INDUSTRIA AER...
# EMB-810C         EMBRAEREMBRAEREMBRAEREMBRAEREMBRAEREMBRAEREMBR...
# EMB-810D         NEIVA INDUSTRIA AERONAUTICAEMBRAERNEIVA INDUST...
# ERJ 190-200 IGW  EMBRAEREMBRAEREMBRAEREMBRAEREMBRAEREMBRAEREMBR...
# F28MK0100        FOKKERFOKKERFOKKERFOKKERFOKKERFOKKERFOKKERFOKK...
# PA-34-220T       PIPER AIRCRAFTPIPER AIRCRAFTPIPER AIRCRAFTPIPE...
# S-76C            SIKORSKY AIRCRAFTSIKORSKY AIRCRAFTSIKORSKY AIR...
# ZODIAC CH-640                                                  NaN
#
#                                                          Acidentes
# aeronave_modelo
# 152                                                            100
# 58                                                              80
# 737-8EH                                                         77
# A320-232                                                        96
# AB-115                                                         216
# ATR-72-212A                                                    120
# EMB-201A                                                        79
# EMB-202                                                         97
# EMB-810C                                                       144
# EMB-810D                                                       147
# ERJ 190-200 IGW                                                 76
# F28MK0100                                                       62
# PA-34-220T                                                      62
# S-76C                                                           85
# ZODIAC CH-640    Index(['AB-115', 'EMB-810D', 'EMB-810C', 'ATR-...

# %%
#Manufacture of the models that fall the most (Now in a plot).

fabricantes = avi1['aeronave_fabricante'].value_counts().head(10)
fabricantes.plot.bar(subplots=True, label="Fabricantes" ,figsize=(8, 4), color='indigo')
plt.savefig('fabi')

"""Don´t fly in Cessna Aircraft."""
# Out:
# 'Don´t fly in Cessna Aircraft.'

# %%
#Category that has most accidents.
kind = avi1['aeronave_segmento_aviacao'].value_counts()
kind.plot.bar(color='indigo', figsize=(8, 4))
plt.savefig('tipo')

# %%
#Kind of engine that falls the most.
tipo_motor = avi1['aeronave_tipo_motor'].value_counts()
tipo_motor.plot.bar(color='indigo', figsize=(8, 4))
plt.savefig('prob')

# %% [markdown]
# # Stuff that I didn´t use but I might need someday.

# %%
# #Getting the mean number of seats of the planes above.
# means = []
# seats = []
# for i in model.index:
#     seats.append(i)
  


# # for i in seats:
#        means.append(gb.loc[i])

# meansseats = pd.DataFrame(means)
# #Creating a function to transform from list to dictionary 
# #Yes, I know I could use lambda, but it didn´t worked, so I thought working is better than not working.
# """This means that smaller aircrafts have a bigger chance of suffer a accident"""

# # meansseats.plot.bar()
